# %% [markdown]
# # Дата

# %% [markdown]
# ## Датаны хэмжээ

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
df = pd.read_excel('ch1_sport_test.xlsx',index_col='student_no')
df
# Out:
#             grade  grip  sit-up  score  ranking
# student_no
# 1               1  40.2      34     15        4
# 2               1  34.2      14      7       10
# 3               1  28.8      27     11        7
# 4               2  39.0      27     14        5
# 5               2  50.9      32     17        2
# 6               2  36.5      20      9        9
# 7               3  36.6      31     13        6
# 8               3  49.2      37     18        1
# 9               3  26.0      28     10        8
# 10              3  47.4      32     16        3

# %%
df['grip']
# Out:
# student_no
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: grip, dtype: float64

# %%
df.shape
# Out:
# (10, 5)
